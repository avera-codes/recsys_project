# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplcyberpunk

plt.style.use("cyberpunk")
import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from tqdm import tqdm
import torchutils as tu
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
torch.manual_seed(666)
import faiss

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
df = pd.read_csv("/home/artemiy/recsys_project/data/dataset_new.csv")
df.isna().sum()
# Out:
# url               0
# poster            0
# title             0
# description       6
# rating         7751
# year              0
# genres            1
# cast              0
# country           0
# age               0
# dtype: int64

# %%
# pip install transformers sentencepiece
# import torch
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny2")
model = AutoModel.from_pretrained("cointegrated/rubert-tiny2")
model.cuda()  # uncomment it if you have a GPU
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(83828, 312, padding_idx=0)
#     (position_embeddings): Embedding(2048, 312)
#     (token_type_embeddings): Embedding(2, 312)
#     (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-2): 3 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=312, out_features=312, bias=True)
#             (key): Linear(in_features=312, out_features=312, bias=True)
#             (value): Linear(in_features=312, out_features=312, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=312, out_features=312, bias=True)
#             (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=312, out_features=600, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=600, out_features=312, bias=True)
#           (LayerNorm): LayerNorm((312,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=312, out_features=312, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def embed_bert_cls(text, model, tokenizer):
    t = tokenizer(text, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        model_output = model(**{k: v.to(model.device) for k, v in t.items()})
    embeddings = model_output.last_hidden_state[:, 0, :]
    embeddings = torch.nn.functional.normalize(embeddings)
    return embeddings[0].cpu().numpy()


print(embed_bert_cls("привет мир", model, tokenizer).shape)
# Out:
# (312,)

# %%
df.columns
# Out:
# Index(['url', 'poster', 'title', 'description', 'rating', 'year', 'genres',
#        'cast', 'country', 'age'],
#       dtype='object')

# %%
df['description'].isna().sum()
# Out:
# 6

# %%
# Заполнение пропусков и конвертация в строковый тип
df["description"] = df["description"].fillna("").astype(str)

# %%
# Создание эмбеддингов для описаний
description_embeddings = np.vstack(
    df["description"].apply(lambda x: embed_bert_cls(x, model, tokenizer)).values
)

# %%
# Построение индекса FAISS
index = faiss.IndexFlatL2(description_embeddings.shape[1])
index.add(description_embeddings.astype(np.float32))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12972 entries, 0 to 12971
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   url          12972 non-null  object
#  1   poster       12972 non-null  object
#  2   title        12972 non-null  object
#  3   description  12972 non-null  object
#  4   rating       5221 non-null   float64
#  5   year         12972 non-null  int64
#  6   genres       12971 non-null  object
#  7   cast         12972 non-null  object
#  8   country      12972 non-null  object
#  9   age          12972 non-null  int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 1013.6+ KB

# %%
print(df['country'].unique())
# Out:
# ['Россия' 'США' 'США, Канада' 'Великобритания' 'Украина' 'Россия, Куба'
#  'СССР' 'Россия, Украина' 'США, Германия, Канада, Франция' 'Бразилия'
#  'Испания, Италия' 'Япония' 'Южная Корея'
#  'Норвегия, Великобритания, Финляндия, Швеция' 'Канада' 'США, Франция'
#  'Турция' 'Норвегия' 'Швеция' 'США, Великобритания' 'Индия'
#  'Канада, Великобритания' 'Австралия' 'Беларусь'
#  'Бельгия, Германия, Швеция' 'Германия, Дания, Франция, Швеция'
#  'Германия, Великобритания, Франция'
#  'США, Германия, Великобритания, Швеция' 'Россия, Аргентина'
#  'США, Германия, Италия, Канада' 'Китай' 'Россия, Великобритания' 'Италия'
#  'Германия' 'США, Япония' 'Канада, Франция' 'Россия, Казахстан, Украина'
#  'Беларусь, Украина' 'Бельгия, Германия' 'США, Германия'
#  'Россия, Беларусь' 'США, Германия, Испания, Италия, Франция'
#  'Италия, Великобритания' 'США, Германия, Канада'
#  'Австралия, Великобритания' 'Аргентина' 'Россия, Польша, Украина'
#  'Франция' 'Сербия' 'Великобритания, Финляндия'
#  'США, Канада, Великобритания' 'Таиланд, Южная Корея' 'Испания'
#  'Россия, США' 'Дания, Норвегия, Швеция' 'Испания, Япония' 'Дания'
#  'Австралия, Канада' 'Колумбия' 'Мексика'
#  'США, Австралия, Германия, Канада, Нидерланды, Норвегия, Польша, Великобритания, Финляндия, Франция, Швеция, Япония'
#  'США, Дания, Франция' 'Кипр' 'США, Канада, Мексика' 'Иран' 'Греция'
#  'Германия, Франция, Чешская Республика' 'Казахстан' 'Армения'
#  'Бельгия, Германия, Дания, Исландия, Норвегия, Великобритания, Швеция'
#  'СССР, Таджикистан' 'Бельгия, Великобритания' 'Нидерланды'
#  'Малайзия, Великобритания' 'Израиль' 'США, Австралия' 'Германия, Франция'
#  'Ирландия, Великобритания' 'Канада, Япония'
#  'США, Испания, Колумбия, Мексика' 'Германия, Швеция'
#  'США, Германия, Канада, Великобритания' 'США, Ирландия, Великобритания'
#  'США, Франция, Япония' 'Австралия, Германия, Индия' 'Дания, Ирландия'
#  'Тайвань (Китай)' 'Канада, Новая Зеландия' 'Финляндия, Швеция'
#  'США, Мексика' 'США, Бельгия' 'Греция, Великобритания'
#  'Германия, Норвегия, Швеция' 'Великобритания, Швеция' 'Финляндия'
#  'США, Германия, Франция' 'США, Канада, Новая Зеландия'
#  'США, Канада, Франция' 'Дания, Швеция' 'США, Новая Зеландия'
#  'Австралия, Канада, Великобритания' 'Аргентина, Италия'
#  'США, Мальта, Великобритания' 'Великобритания, Франция'
#  'Корея, Республика, Великобритания, Франция, Япония'
#  'США, Германия, Великобритания' 'США, Ирландия, Канада, Великобритания'
#  'Ирландия, Канада' 'СССР, Болгария' 'Россия, СССР'
#  'СССР, Германия, Италия, Польша' 'Россия, Турция'
#  'Венгрия, Ирландия, Канада' 'Германия, Дания, Швеция'
#  'США, Германия, Италия, Франция' 'СССР, Япония'
#  'США, Германия, Италия, Китай, Великобритания, Франция, Япония, Южная Корея'
#  'Россия, Болгария' 'Австрия, Германия' 'Франция, Япония'
#  'Чешская Республика' 'Россия, Германия, Италия, Польша, Франция'
#  'США, Италия, Великобритания' 'Румыния' 'Италия, Франция' 'США, Гонконг'
#  'Россия, Португалия' 'США, Норвегия' 'Польша'
#  'США, Германия, Италия, Югославия' 'Бразилия, Индия' 'Россия, Китай'
#  'Россия, Турция, Украина' 'США, Канада, Япония'
#  'США, Венгрия, Германия, Испания, Италия, Канада, Великобритания, Франция, Чешская Республика'
#  'Германия, Дания, Исландия, Норвегия, Финляндия, Швеция'
#  'Россия, Беларусь, Украина' 'Россия, Италия'
#  'США, Австралия, Великобритания' 'Германия, Канада, Великобритания'
#  'Австралия, Польша' 'Австрия, Бельгия, Германия, Дания, Швейцария'
#  'Германия, Италия, Канада, Нидерланды'
#  'США, Индонезия, Франция, Южная Корея' 'Россия, Италия, Великобритания'
#  'Франция, Швеция' 'Россия, Китай, Украина' 'США, Мексика, Франция'
#  'США, Канада, Великобритания, Южная Африка' 'США, Италия' 'Перу'
#  'Австралия, Китай, Польша' 'Дания, Индия, Таиланд'
#  'США, Великобритания, Франция' 'Канада, Швейцария'
#  'США, Чешская Республика' 'США, Южная Корея' 'Ирландия'
#  'США, Ирландия, Великобритания, Франция' 'Россия, Германия, Польша'
#  'Канада, Великобритания, Франция' 'США, Канада, Франция, Япония'
#  'Бельгия, Норвегия' 'Германия, Италия' 'Германия, Италия, Франция'
#  'США, Германия, Словакия' 'Германия, Италия, Великобритания'
#  'Германия, Дания, Исландия, Фарерские острова' 'Чили'
#  'Россия, Беларусь, Болгария' 'США, Испания, Италия, Франция'
#  'США, Испания, Мексика, Великобритания, Япония' 'Россия, Армения'
#  'Австрия, Германия, Япония' 'Австрия, Великобритания'
#  'Германия, Дания, Норвегия, Швеция' 'Россия, Латвия' 'США, Польша'
#  'США, Дания, Канада, Сингапур'
#  'США, Германия, Греция, Италия, Великобритания' 'СССР, Франция'
#  'Россия, Сербия' 'США, Венгрия, Канада, Великобритания'
#  'США, Китай, Тайвань (Китай), Южная Корея' 'США, Испания'
#  'Ирландия, Новая Зеландия'
#  'Россия, Германия, Великобритания, Украина, Чешская Республика'
#  'Испания, Португалия' 'Германия, Италия, Великобритания, Франция'
#  'Исландия' 'Япония, Южная Корея'
#  'Бельгия, Франция, Чешская Республика, Швейцария'
#  'Австралия, Канада, Новая Зеландия'
#  'Россия, Германия, Дания, Польша, Франция'
#  'США, Германия, Канада, Великобритания, Япония'
#  'Марокко, Саудовская Аравия'
#  'США, Канада, Тайвань (Китай), Франция, Япония' 'Венесуэла' 'Бельгия'
#  'Германия, Дания, Норвегия, Финляндия, Швеция' 'Китай, Франция'
#  'США, Индия, Франция' 'Россия, Испания'
#  'США, Китай, Нидерланды, Польша, Тайвань (Китай), Чешская Республика, Япония'
#  'Австрия' 'США, Бразилия' 'Германия, Финляндия'
#  'Испания, Нидерланды, Финляндия, Франция, Япония'
#  'Испания, Великобритания' 'Швейцария' 'Новая Зеландия, Великобритания'
#  'СССР, Польша' 'Бразилия, Португалия' 'Китай, Южная Корея'
#  'Италия, Япония' 'Канада, Китай' 'Россия, Польша'
#  'Бельгия, Германия, Франция' 'Германия, Чешская Республика'
#  'Германия, Канада, Швейцария'
#  'США, Испания, Канада, Великобритания, Франция' 'Дания, Норвегия'
#  'США, Аргентина' 'США, Венесуэла' 'США, Канада, Колумбия'
#  'Новая Зеландия' 'США, Алжир, Канада, Великобритания, Франция'
#  'Россия, Германия, Нидерланды, Финляндия'
#  'США, Испания, Италия, Великобритания, Франция' 'Эстония'
#  'Германия, Испания, Канада, Великобритания' 'Австралия, Ирландия'
#  'США, Колумбия' 'Израиль, Франция' 'Германия, Дания'
#  'США, Австралия, Канада' 'Россия, Италия, Украина'
#  'США, Германия, Мексика' 'США, Нидерланды, Новая Зеландия, Франция'
#  'Франция, Швейцария' 'США, Германия, Италия' 'Иран, Узбекистан'
#  'Португалия' 'Бельгия, Испания, Италия' 'Бразилия, Ирландия, Испания'
#  'Египет' 'Сингапур' 'Италия, Чили'
#  'Бельгия, Германия, Канада, Великобритания, Франция'
#  'Португалия, Франция' 'Литва, Польша, Финляндия, Франция, Швеция'
#  'США, Югославия' 'Россия, Аргентина, Израиль, Великобритания, Украина'
#  'Аргентина, Южная Корея' 'Бельгия, Франция'
#  'Германия, Испания, Великобритания, Франция'
#  'США, Исландия, Испания, Нидерланды, Великобритания, Франция, Швейцария'
#  'Германия, Люксембург, Великобритания' 'Венгрия'
#  'Германия, Италия, Канада, Франция, Швейцария' 'Бельгия, Швейцария'
#  'США, Нидерланды' 'Австрия, Германия, Чешская Республика'
#  'Испания, Польша' 'США, Ирландия, Канада'
#  'Бразилия, Канада, Португалия, Франция' 'США, Швеция'
#  'Германия, Испания, Италия, Чешская Республика' 'Италия, Южная Корея'
#  'Южная Африка' 'Хорватия' 'Австралия, Франция' 'Саудовская Аравия'
#  'Венгрия, Великобритания' 'США, Канада, Великобритания, Филиппины'
#  'Россия, Германия' 'Австралия, Канада, Сингапур, Франция' 'Россия, Литва'
#  'Германия, Испания, Италия, Великобритания, Франция, Швейцария'
#  'Германия, Канада'
#  'Гонконг, Китай, Макао, Великобритания, Тайвань (Китай)'
#  'Испания, Португалия, Франция'
#  'СССР, Болгария, Венгрия, Германия, Польша, Румыния'
#  'Канада, Мексика, Франция' 'США, Бельгия, Великобритания'
#  'Латвия, Украина' 'Дания, Норвегия, Финляндия, Швеция' 'Испания, Куба'
#  'США, Перу' 'Иордания, Ливан, Сирийская Арабская Республика, Судан'
#  'Германия, Люксембург' 'Германия, Испания, Италия, Швейцария'
#  'Дания, Литва, Норвегия, Финляндия, Швеция'
#  'США, Великобритания, Чешская Республика' 'Канада, Южная Корея'
#  'Аргентина, Великобритания' 'СССР, Германия'
#  'Бельгия, Франция, Швейцария' 'Германия, Япония'
#  'Бельгия, Германия, Финляндия' 'Германия, Италия, Люксембург'
#  'США, Италия, Китай, Япония' 'США, Индия' 'Грузия, Украина'
#  'Финляндия, Франция' 'США, Бельгия, Германия, Великобритания, Франция'
#  'Австралия, Новая Зеландия' 'Германия, Ирландия, Великобритания'
#  'Австралия, Германия' 'США, Филиппины'
#  'США, Германия, Италия, Южная Африка' 'Люксембург, Франция'
#  'Германия, Польша' 'Германия, Нидерланды, Южная Африка' 'США, Ирландия'
#  'США, Франция, Южная Корея' 'Колумбия, Эквадор' 'Китай, Португалия'
#  'Бельгия, Италия, Франция'
#  'Дания, Исландия, Норвегия, Финляндия, Швеция, Южная Африка'
#  'США, Бельгия, Германия, Франция' 'Германия, Литва, Швеция'
#  'Дания, Исландия, Норвегия, Финляндия, Швеция' 'Израиль, Норвегия'
#  'США, Германия, Великобритания, Франция, Япония' 'Иордания'
#  'Дания, Финляндия, Швеция' 'Австрия, Германия, Франция' 'Бельгия, Дания'
#  'США, Израиль' 'СССР, Испания' 'Италия, Швейцария, Япония'
#  'Австрия, Германия, Испания, Италия, Франция' 'США, Италия, Франция'
#  'Россия, США, Франция'
#  'Дания, Норвегия, Великобритания, Финляндия, Швеция'
#  'Ямайка, Южная Корея' 'США, Польша, Япония'
#  'Бельгия, Нидерланды, Южная Африка'
#  'США, Германия, Великобритания, Франция' 'Испания, Франция'
#  'США, Колумбия, Мексика' 'США, Австралия, Новая Зеландия'
#  'Аргентина, Чили' 'Индия, ОАЭ' 'Россия, Франция, Швейцария'
#  'Бельгия, Израиль, Франция' 'Германия, Ирландия, Канада'
#  'Россия, Казахстан' 'США, Ботсвана, Великобритания, Южная Африка'
#  'Австралия, Ирландия, Филиппины' 'Бельгия, Нидерланды'
#  'Германия, Индия, Франция' 'Коста-Рика' 'Словения, Хорватия'
#  'США, Аргентина, Мексика, Нидерланды, Перу, Чили' 'Словения'
#  'Россия, Ливан' 'Новая Зеландия, Южная Корея'
#  'Австралия, Германия, Франция' 'США, Китай' 'Китай, Япония'
#  'Великобритания, Швейцария' 'Таиланд'
#  'США, Ирландия, Латвия, Южная Африка'
#  'Австрия, Бельгия, Германия, Италия, Франция, Швейцария, Япония'
#  'США, Бразилия, Великобритания, Южная Африка, Япония' 'США, Дания'
#  'Китай, Япония, Южная Корея' 'Бельгия, Германия, Франция, Швейцария'
#  'Бельгия, Канада, Франция' 'Испания, Чили' 'Норвегия, Франция, Швеция'
#  'США, Австралия, Бельгия, Дания, Ирландия, Исландия, Нидерланды, Норвегия, Португалия, Великобритания, Финляндия, Франция, Япония'
#  'Россия, Молдова, Украина' 'Аргентина, Уругвай' 'Пакистан'
#  'Россия, Хорватия' 'Польша, Япония' 'США, Австрия, Великобритания'
#  'Испания, Мексика' 'Аргентина, Бразилия' 'Аргентина, Бразилия, Уругвай'
#  'США, Германия, Италия, Франция, Швейцария'
#  'Германия, Франция, Южная Африка' 'Польша, Украина, Чешская Республика'
#  'Австрия, Германия, Швейцария' 'США, Великобритания, Япония'
#  'Зимбабве, Южная Африка' 'Болгария, Германия, Польша'
#  'Канада, Южная Африка' 'США, Япония, Южная Корея' 'США, Дания, Канада'
#  'Нидерланды, Великобритания' 'Корея, Республика' 'Гонконг, Китай'
#  'Германия, Испания' 'Россия, США, Великобритания' 'Мексика, Чили'
#  'США, Германия, Италия, Великобритания, Франция'
#  'Германия, Франция, Южная Корея' 'США, Великобритания, Финляндия'
#  'Малайзия' 'Латвия' 'Индия, Испания, Турция' 'США, Китай, Франция'
#  'Италия, Сингапур' 'Болгария' 'Австралия, Ирландия, Мексика'
#  'США, Китай, Япония, Южная Корея' 'Италия, Польша'
#  'Германия, Дания, Великобритания' 'Германия, Румыния'
#  'США, Канада, Филиппины' 'Австралия, Канада, Колумбия' 'Россия, Молдова'
#  'США, Монголия' 'Норвегия, Швеция']

# %%
def find_shows(query, df, model, tokenizer, index, top_k=int):
    # Создание эмбеддингов для запроса
    query_embedding = embed_bert_cls(query, model, tokenizer).reshape(1, -1)

    # Поиск топ-K ближайших соседей с использованием Faiss
    _, top_k_indices = index.search(query_embedding.astype(np.float32), top_k)

    # Извлечение соответствующих строк из DataFrame
    result = df.iloc[top_k_indices[0]].copy()

    # Вычисление косинусного сходства для сортировки (опционально)
    similarities = cosine_similarity(
        query_embedding, description_embeddings[top_k_indices[0]]
    ).flatten()
    result["similarity"] = similarities

    return result.sort_values("similarity", ascending=False)

# %%
query = "В центре истории сериала оказываются молодые люди, только недавно окончившие сложную образовательную программу в престижной финансовой компании, считающейся одним из мировых лидеров в своей области."
find_shows(query, df, model, tokenizer, index, 10)
# Out:
#                                                      url  \
# 8599     https://kino.mail.ru/series_913786_zhurnalyugi/
# 10838       https://kino.mail.ru/series_910728_partneri/
# 4212            https://kino.mail.ru/series_920337_deti/
# 5494    https://kino.mail.ru/series_935923_pokolenie_vi/
# 2557   https://kino.mail.ru/series_931231_univer_star...
# 6988         https://kino.mail.ru/series_905734_startap/
# 3164   https://kino.mail.ru/series_920617_bolshaya_igra/
# 1187    https://kino.mail.ru/series_913462_proekt_orfei/
# 7438      https://kino.mail.ru/series_925222_industriya/
# 3669            https://kino.mail.ru/series_836537_kult/
#
#                                                   poster  \
# 8599   https://resizer.mail.ru/p/0be34b07-2629-5f92-9...
# 10838  https://resizer.mail.ru/p/57fc6ba2-4f2b-5f89-a...
# 4212   https://resizer.mail.ru/p/ff954a9b-90be-5f86-a...
# 5494   https://resizer.mail.ru/p/e02be7a2-a53f-55df-8...
# 2557   https://resizer.mail.ru/p/59d883c5-b138-502b-9...
# 6988   https://resizer.mail.ru/p/dc977c76-65b1-53bf-a...
# 3164   https://resizer.mail.ru/p/1be6727a-dc55-5deb-9...
# 1187   https://resizer.mail.ru/p/f7517461-3c97-5f47-9...
# 7438   https://resizer.mail.ru/p/cc620e62-7c2a-5369-8...
# 3669   https://resizer.mail.ru/p/4ecb8a1f-f979-55a0-9...
#
#                        title  \
# 8599               Журналюги
# 10838               Партнеры
# 4212         Никто не узнает
# 5494          Поколение «Ви»
# 2557   Универ. 10 лет спустя
# 6988                 Стартап
# 3164            Большая игра
# 1187          Проект «Орфей»
# 7438               Индустрия
# 3669                   Культ
#
#                                              description  rating  year  \
# 8599   В центре событий сериала «Журналюги» — двое пр...     NaN  2016
# 10838  В центре событий комедийного сериала «Партнеры...     NaN  1979
# 4212   Главные герои сериала — успешные, состоявшиеся...     6.9  2022
# 5494   Действие сериала разворачивается в единственно...     5.9  2023
# 2557   Продолжение популярного молодежного ситкома «У...     6.6  2021
# 6988   В центре событий комедийного сериала «Стартап»...     NaN  2015
# 3164   Действие фантазийной комедии разворачивается з...     7.2  2018
# 1187   Пятеро лучших студентов-медиков получают уника...     6.7  2016
# 7438   Выпускники финансовых школ и институтов вступа...     NaN  2020
# 3669   Несколько молодых ребят из России становятся а...     5.9  2015
#
#                                          genres  \
# 8599                            Драма, Детектив
# 10838                                   Комедия
# 4212                           Драма, Мелодрама
# 5494   Фантастика, Комедия, Боевик, Приключения
# 2557                                    Комедия
# 6988                                    Комедия
# 3164                             Комедия, Спорт
# 1187                 Драма, Фантастика, Триллер
# 7438                                      Драма
# 3669                         Драма, Приключения
#
#                                                     cast     country  age  \
# 8599   Никита Тарасов, Александр Ляпин, Алексей Барду...      Россия   16
# 10838  Уилфрид Хайд-Уайт, Мартин Шорт, Элли Миллс, Дж...         США   12
# 4212   Юрий Быков, Евгения Брик, Кирилл Сафонов, Викт...      Россия   16
# 5494   Джаз Синклер, Патрик Шварценеггер, Лиззи Бродв...         США   18
# 2557   Арарат Кещян, Станислав Ярушин, Александр Март...      Россия   16
# 6988   Парвеш Шина, Питер Шинкода, Джулия Карпентер, ...         США   16
# 3164   Дмитрий Колчин, Сергей Лавыгин, Максим Лагашки...      Россия   16
# 1187   Лиза Смит, Стефани ван Лирсум, Тобиас Нироп, В...  Нидерланды   16
# 7438   Эндрю Бакан, Александр Девриент, Джо Херст, Дж...         США   18
# 3669   Дмитрий Марьянов, Татьяна Арнтгольц, Артур Соп...      Россия   16
#
#        similarity
# 8599     0.766532
# 10838    0.751230
# 4212     0.743262
# 5494     0.742140
# 2557     0.739653
# 6988     0.739078
# 3164     0.736978
# 1187     0.735264
# 7438     0.734215
# 3669     0.731506
